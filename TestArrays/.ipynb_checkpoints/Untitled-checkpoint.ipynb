# %%
using PyPlot
# Out:
# INFO: Recompiling stale cache file /home/efefer/.julia/lib/v0.4/PyPlot.ji for module PyPlot.
# INFO: Recompiling stale cache file /home/efefer/.julia/lib/v0.4/PyCall.ji for module PyCall.
# INFO: Recompiling stale cache file /home/efefer/.julia/lib/v0.4/MacroTools.ji for module MacroTools.
# INFO: Recompiling stale cache file /home/efefer/.julia/lib/v0.4/LaTeXStrings.ji for module LaTeXStrings.

# %%
x = linspace(-5.0,5.0,200);
y = sin(x);
plot(x,y,linewidth=2,color="red",label="Sine")
grid()
legend()
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x65ea150>)
# PyObject <matplotlib.legend.Legend object at 0x682e210>
